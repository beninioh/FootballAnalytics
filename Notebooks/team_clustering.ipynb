# %% [markdown]
# ### Based on teams data, let's try to cluster the teams.
#
# In order to process the team clustering, we will first reduce space's dimension using tnse.
# Then, we will use the k-means algorithm to proper cluster the teams.

# %%
from analysis.teams_clustering import *

sns.set_style('darkgrid')

get_cotes(['ligue1', 'prleague', 'liga'], ['1617', '1718', '1819', '1920'], 13, 7)
# Out:
# (           team  league season  cluster
#  0        Monaco  ligue1   1617        1
#  1         Paris  ligue1   1617        1
#  2          Nice  ligue1   1617        2
#  3          Lyon  ligue1   1617        1
#  4     Marseille  ligue1   1617        1
#  ..          ...     ...    ...      ...
#  235  Celta_vigo    liga   1920        4
#  236       Eibar    liga   1920        0
#  237    Mallorca    liga   1920        4
#  238     Leganes    liga   1920        0
#  239    Espanyol    liga   1920        0
#
#  [240 rows x 4 columns],
#            0         1         2         3         4         5         6
#  0  0.417391  0.239437  0.486239  0.661765  0.478873  0.346154  0.533333
#  1  0.760563  0.492857  0.661290  0.898305  0.745098  0.683333  0.765766
#  2  0.481481  0.225806  0.491935  0.597403  0.471910  0.333333  0.500000
#  3  0.264706  0.180328  0.402597  0.433333  0.363636  0.357143  0.440000
#  4  0.309859  0.176471  0.325843  0.363636  0.449153  0.340909  0.600000
# ...
